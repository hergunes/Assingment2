# %% [markdown]
# <a href="https://colab.research.google.com/github/hergunes/Assingment2/blob/main/Assignment_2_student_he.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.sample()
# Out:
#         id           name      date manner_of_death  armed   age gender race  \
# 1547  1739  Dylan Liberti  27/07/16            shot  knife  24.0      M    W
#
#             city state  signs_of_mental_illness threat_level  flee  \
# 1547  Scottsdale    AZ                    False        other  Foot
#
#       body_camera
# 1547         True

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(kill.gender, kill.age, hue = kill.manner_of_death, data = kill);

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(10, 6))
sns.swarmplot(kill.gender, kill.age, hue = kill.manner_of_death, data = kill);

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = kill.city.value_counts()[:12]
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x = city_freq.index, y = city_freq.values, data = kill)
ax.set_xticklabels(city_freq.index, rotation = 45)
ax.set_title("Most dangerous cities", color="blue");

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.countplot(x = "city", order = city_freq.index, data = kill)
ax.set_xticklabels(city_freq.index, rotation = 45)
ax.set_title("Most dangerous cities", color="blue");

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = kill.state.value_counts()[:20]
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x = state_freq.index, y = state_freq.values, data = kill)
ax.set_xticklabels(state_freq.index, rotation = 45)
ax.set_title("Most dangerous state", color = "blue");

# %%
# with seaborn countplot
fig, ax = plt.subplots(figsize = (8,5))
ax = sns.countplot(data = kill, x = "state", order = state_freq.index)
ax.set_title("Most dangerous state")
ax.set_xticklabels(state_freq.index, rotation = 45);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
fig, ax = plt.subplots(figsize = (8, 5))
ax = sns.countplot(data = kill, x = "signs_of_mental_illness", order = illness.index);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
fig, ax=plt.subplots(figsize = (8,5))

ax = sns.countplot(data = kill, x = "threat_level", order = threads_freq.index);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn
fig, ax=plt.subplots(figsize = (8, 5))

ax = sns.countplot(data = kill, x = "flee", order = flee_freq.index)
